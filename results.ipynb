# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
from results import Results

# %%
r = Results()
df= r.pickle2df("arResult_202104")
print("ok")
# Out:
# arResult_202104.pickle is loaded.
# ok

# %%
df
# Out:
#                      race wthr  fst  sec  thd     win    quin     exac  \
# 0     2021年4月1日(木) 伊勢崎 1R    晴    2    6    7    140円    580円     640円
# 1     2021年4月1日(木) 伊勢崎 2R    晴    6    1    2  6,520円  5,250円  12,870円
# 2     2021年4月1日(木) 伊勢崎 3R    晴    4    2    3    460円  1,350円   2,280円
# 3     2021年4月1日(木) 伊勢崎 4R    晴    8    7    4    150円    470円     590円
# 4     2021年4月1日(木) 伊勢崎 5R    晴    7    8    2    400円    230円   1,430円
# ..                    ...  ...  ...  ...  ...     ...     ...      ...
# 505   2021年4月30日(金) 飯塚 8R    晴    2    7    6    140円  1,920円   2,010円
# 506   2021年4月30日(金) 飯塚 9R    晴    7    1    6    760円  1,520円   3,990円
# 507  2021年4月30日(金) 飯塚 10R    晴    4    1    5    110円    500円     680円
# 508  2021年4月30日(金) 飯塚 11R    晴    3    6    1    230円    950円   1,120円
# 509  2021年4月30日(金) 飯塚 12R    晴    2    3    7    120円  2,680円   3,050円
#
#         trio      trif  fv1  fv2  fv3
# 0     2,040円    3,830円    2    5    8
# ...

# %%
win_df = r.simula_favorite(df, "単勝")
win_df[:10]
# Out:
#                    race wthr  fst  sec  thd     win  fv1  fv2  fv3 jdg  divd  \
# 0   2021年4月1日(木) 伊勢崎 1R    晴    2    6    7    140円    2    5    8   o  4200
# 1   2021年4月1日(木) 伊勢崎 2R    晴    6    1    2  6,520円    8    1    2   x     0
# 2   2021年4月1日(木) 伊勢崎 3R    晴    4    2    3    460円    7    4    1   x     0
# 3   2021年4月1日(木) 伊勢崎 4R    晴    8    7    4    150円    8    7    3   o  4500
# 4   2021年4月1日(木) 伊勢崎 5R    晴    7    8    2    400円    8    7    6   x     0
# 5   2021年4月1日(木) 伊勢崎 6R    晴    7    8    5    200円    7    5    6   o  6000
# 6   2021年4月1日(木) 伊勢崎 7R    晴    6    2    4    140円    6    5    3   o  4200
# 7   2021年4月1日(木) 伊勢崎 8R    晴    8    4    5    140円    8    7    1   o  4200
# 8   2021年4月1日(木) 伊勢崎 9R    晴    8    4    2    100円    8    3    2   o  3000
# 9  2021年4月1日(木) 伊勢崎 10R    晴    8    3    4    100円    8    3    1   o  3000
#
#    blnc
# 0  1200
# 1 -3000
# 2 -3000
# 3  1500
# 4 -3000
# 5  3000
# 6  1200
# 7  1200
# 8     0
# 9     0

# %%
r.arSummary(df)
# Out:
#    race ticket  Hit rate  Recovery  Balance
# 0   510     単勝      0.46      0.70  -454800
# 1   510    2連複      0.41      0.60  -612000
# 2   510    2連単      0.41      0.52  -730400
# 3   510    3連複      0.14      0.68  -482700
# 4   510    3連単      0.14      0.53  -712500

# %%
pd.DataFrame().empty
# Out:
# True

# %%
df.sum(numeric_only=True)
# Out:
# fst    2527
# sec    2281
# thd    2291
# fv1    2830
# fv2    2395
# fv3    2328
# dtype: int64
